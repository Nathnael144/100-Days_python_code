# %% [markdown]
# Day One Code
#
# Notes from Day 1
#
# The print statement is used to output strings
#
# Strings are strings of characters
#
# String Concatenation is done with the + sign
#
# New lines can be created with a \ and the letter n

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World\nHello World")
# Out:
# Hello World
# Hello World

# %%
print("Hello"+" "+"Nathan")
# Out:
# Hello Nathan

# %%
print("Hello " + input("What is your name ?"))
# Out:
# Hello Nathan

# %%
x=input("What is your name ?")
print("Hello " + x)
print(len(x))
# Out:
# Hello Nathan
# 6

# %% [markdown]
# Exercise
#
# We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice. Write 3 lines of code to switch the contents of the variables. You are not allowed to type the words "milk" or "juice". You are only allowed to use variables to solve this exercise.
#
# glass1 = "milk"
#
# glass2 = "juice"

# %%
temp = glass1
glass1 = glass2
glass2 = temp

# %% [markdown]
# Project

# %%
print("Welcome to Band name generator")
city= input("The name of the city I grew up in ?\n")
print (city) 
animal=input("My favorite animal?\n")
print (animal )
print("your band name could be "+ city +" "+ animal)
# Out:
# Welcome to Band name generator
# Gimjabet
# Cow
# your band name could be Cow
